# %%
import requests
import pandas as pd
import json
from datetime import datetime, timezone
import time

from typing import Dict, List, Optional, Union

from osrs_filter import OSRSItemFilter

from llm.client import ModelConfig, get_chat_response, init_client, remove_thinking_tags
from utils.config import settings
# Configuration
BASE_URL = "https://prices.runescape.wiki/api/v1/osrs"

# IMPORTANT: Set a descriptive User-Agent as required by the API
# Replace with your own descriptive user agent
USER_AGENT = "learning pandas with osrs - @sf1tzp"

# Default headers with proper User-Agent
HEADERS = {
    'User-Agent': USER_AGENT,
    'Accept': 'application/json'
}

print(f"Using User-Agent: {USER_AGENT}")
print(f"Base URL: {BASE_URL}")
# Out:
# Using User-Agent: learning pandas with osrs - @sf1tzp
# Base URL: https://prices.runescape.wiki/api/v1/osrs

# %%
# Reinitialize with forced reload to clear cached timezone-naive data
print("Reinitializing OSRSItemFilter with fresh data...")
item_filter = OSRSItemFilter(user_agent=USER_AGENT)
item_filter.load_data(force_reload=True)
item_filter.apply_filter(
    margin_min=3000,
    margin_pct_min=3,
    max_hours_since_update=0.25,
)
print(f"Requsting volume data at: {datetime.now()}")
item_filter.load_volume_data(max_items=10000)
print(f"Volume data fetching complete at: {datetime.now()}")

# Example of saving filtered data to files in different formats
print("Saving filtered data to files...")

# Save to Pickle (best for preserving all data types)
item_filter.save("filtered_items.pkl", format="pickle")
# Out:
# Reinitializing OSRSItemFilter with fresh data...
# Loading data for filtering...
# ✅ Computed derived columns
# ✅ Loaded 4182 items with price data
# Starting with 4180 items with price data
# After margin >= 3,000 GP: 1083 items
# After margin >= 3%: 845 items
# After max 0.25h since update: 307 items
# Sorted by last_bought_time (descending)
# Requsting volume data at: 2025-08-05 17:48:47.726486
# Fetching volume data for 307 items...
#   Processed 10/307 items...
#   Processed 20/307 items...
#   Processed 30/307 items...
#   Processed 40/307 items...
#   Processed 50/307 items...
#   Processed 60/307 items...
#   Processed 70/307 items...
#   Processed 80/307 items...
#   Processed 90/307 items...
#   Processed 100/307 items...
#   Processed 110/307 items...
#   Processed 120/307 items...
#   Processed 130/307 items...
#   Processed 140/307 items...
#   Processed 150/307 items...
#   Processed 160/307 items...
#   Processed 170/307 items...
#   Processed 180/307 items...
#   Processed 190/307 items...
#   Processed 200/307 items...
#   Processed 210/307 items...
#   Processed 220/307 items...
#   Processed 230/307 items...
#   Processed 240/307 items...
#   Processed 250/307 items...
#   Processed 260/307 items...
#   Processed 270/307 items...
#   Processed 280/307 items...
#   Processed 290/307 items...
#   Processed 300/307 items...
# ✅ Successfully enriched 307/307 items with volume data
# Volume data fetching complete at: 2025-08-05 17:53:29.012926
# Saving filtered data to files...
# Data saved successfully to filtered_items.pkl
# True

# %%
# item_filter.save("filtered_items.pkl", format="pickle")

# %%
# Initialize a new filter instance
loaded_filter = OSRSItemFilter(user_agent=USER_AGENT)

# Load from the saved pickle file (preserves all data types)
loaded_filter.load_from_file("filtered_items.pkl", format="pickle")

# Current approach: volume_24h + flip_efficiency
loaded_filter = OSRSItemFilter(user_agent=USER_AGENT)
loaded_filter.load_from_file("filtered_items.pkl", format="pickle")
loaded_filter.apply_filter(
    volume_24h_min=150,
    sold_price_max=12000000,
    sort_by=("flip_efficiency", "desc"),
    limit=10
)

with open("over-here!.txt", "w") as file:
    file.write(str(loaded_filter))

# Save with improved formatting for LLM
loaded_filter.save("loaded_filter.json", format="json")


loaded_filter
# Out:
# Loaded 307 items from filtered_items.pkl
# ✅ Computed derived columns
# Loaded 307 items from filtered_items.pkl
# ✅ Computed derived columns
# Starting with 307 items with price data
# After sell price <= 12,000,000: 300 items
# After 24h volume >= 150: 119 items
# Sorted by flip_efficiency (descending)
# Limited to top 10 items (from 119)
# Data saved successfully to loaded_filter.json
# OSRS Price Semantics (counterintuitive):
#    • sold_price = what you can BUY at (instant sell order fill price)
#    • bought_price = what you can SELL at (instant buy order fill price)
#    • margin_gp = bought_price - sold_price = potential profit per item
#
# Trend Values: increasing, decreasing, flat
#
# OSRSItemFilter Results (10 items)
#                  name margin_gp margin_pct flip_efficiency  buy_limit sold_price bought_price sold_volume_20m bought_volume_20m avg_sold_price_20m avg_bought_price_20m avg_margin_gp_20m sold_volume_1h bought_volume_1h avg_sold_price_1h avg_bought_price_1h avg_margin_gp_1h sold_price_trend_1h bought_price_trend_1h sold_volume_24h bought_volume_24h avg_sold_price_24h avg_bought_price_24h avg_margin_gp_24h sold_price_trend_24h bought_price_trend_24h sold_price_trend_1w bought_price_trend_1w sold_price_trend_1m bought_price_trend_1m        sold_time      bought_time bought_time_rel sold_time_rel
#        Brimstone ring   283,143      5.04%      11,184,148        8.0  5,618,294    5,901,437              11                 6          5,735,760            5,899,096           163,336             32               47         5,641,987           5,782,165          147,711          decreasing            increasing             586               615          5,505,776            5,615,291           118,669           decreasing             decreasing          increasing            increasing          increasing            increasing 2025-08-05 17:47 2025-08-05 17:39         15m ago        8m ago
#        Fremennik kilt   313,603      7.52%       5,488,052        8.0  4,172,096    4,485,699               2                 6          4,197,843            4,415,752           262,109              9               26         4,154,261           4,320,532          181,054          decreasing            increasing             274               309          4,033,319            4,152,851           125,474           decreasing             decreasing          increasing            increasing          increasing            increasing 2025-08-05 17:44 2025-08-05 17:42         12m ago       11m ago
# Accursed sceptre (au)   197,684      4.75%       2,767,576        8.0  4,159,715    4,357,399               0                 4                N/A            4,352,082               N/A             10               18         4,071,227           4,322,158          244,549          decreasing            increasing             199               247          4,054,600            4,165,083           125,140           decreasing             decreasing          increasing            increasing          decreasing            decreasing 2025-08-05 17:32 2025-08-05 17:40         15m ago       23m ago
#          Antler guard   143,827      4.32%       2,445,059        NaN  3,328,417    3,472,244               8                 2          3,337,053            3,472,244           138,928             15               19         3,327,603           3,457,674          149,916          decreasing            decreasing             337               413          3,192,918            3,317,191           123,810           decreasing             decreasing          increasing            increasing          decreasing            decreasing 2025-08-05 17:44 2025-08-05 17:44         11m ago       11m ago
#       Occult necklace    22,302      5.22%       2,185,596        8.0    427,000      449,302              12                30            436,307              448,441            12,134             84              112           440,232             452,795           12,800                flat            decreasing           1,599             2,096            443,763              455,482            11,703           decreasing                   flat          increasing            increasing          decreasing            decreasing 2025-08-05 17:45 2025-08-05 17:46          9m ago        9m ago
#    Dragon impling jar    11,599      3.07%       2,180,612    18000.0    377,555      389,154              84                59            379,611              389,075             8,430            191              185           378,265             388,628            9,838                flat            decreasing           4,779               947            386,424              393,271             7,571           decreasing             decreasing          increasing            increasing          decreasing            decreasing 2025-08-05 17:45 2025-08-05 17:39         15m ago        9m ago
#     Ahrim's robeskirt    44,644      3.32%       2,165,234       15.0  1,345,356    1,390,000              10                18          1,355,174            1,379,433            24,259             39               58         1,363,693           1,386,503           24,680          decreasing                  flat             683               780          1,350,023            1,376,525            26,787           decreasing             decreasing          increasing            increasing          decreasing            decreasing 2025-08-05 17:41 2025-08-05 17:47          8m ago       14m ago
#    Obsidian platelegs    30,629      3.58%       1,822,425       70.0    855,248      885,877               7                48            847,206              868,133            20,927             32               87           842,213             857,854           15,641          increasing            increasing           1,060               901            862,313              882,210            20,852           decreasing             decreasing          decreasing            decreasing          increasing            increasing 2025-08-05 17:47 2025-08-05 17:44         10m ago        8m ago
#            Seers ring    42,696      3.36%       1,771,884        8.0  1,271,909    1,314,605               9                14          1,279,257            1,321,709            42,452             49               34         1,292,942           1,351,703           56,482                flat            decreasing           1,026               875          1,238,268            1,269,296            32,592           decreasing                   flat          increasing            increasing          increasing            increasing 2025-08-05 17:46 2025-08-05 17:45          9m ago        8m ago
#  Eclipse moon tassets    31,263      3.78%       1,500,624       15.0    827,832      859,095               9                 9            832,041              859,111            24,039             47               49           843,552             864,484           16,514          decreasing            decreasing             267               816            904,544              933,491            29,141           decreasing             decreasing                flat                  flat          decreasing            decreasing 2025-08-05 17:45 2025-08-05 17:45          9m ago       10m ago

# %%
# Prototype LLM interaction using get_generate_response
from llm.client import ModelConfig, get_generate_response
# Configure qwen3:14b with 10k token context
model_config = ModelConfig.create_default("qwen3:14b")
model_config.options.num_ctx = 20000  # 10k token context

# Read the prompt.txt file as system prompt
with open("prompt.txt", "r") as f:
    system_prompt = f.read()

# %%
with open("loaded_filter.json", "r") as f:
    content = f.read()

# Use the loaded_filter's string representation as user prompt context
user_prompt = f"{content}"


print("Sending request to LLM...")
print(f"Model: {model_config.name}")
print(f"Context size: {model_config.options.num_ctx}")
print(f"System prompt length: {len(system_prompt)} chars")
print(f"User prompt length: {len(user_prompt)} chars")
print("=" * 50)

# Get response from LLM
response = get_generate_response(
    model_config=model_config,
    system_prompt=system_prompt,
    user_prompt=user_prompt
)

# Clean the response by removing thinking tags
cleaned_response = remove_thinking_tags(response.response)

print("Cleaned response (without thinking tags):")
print("=" * 50)
print(cleaned_response)

# Save the cleaned response to a separate file
with open("llm_trading_analysis_json.md", "w") as f:
    f.write("=== Clean LLM Trading Analysis ===\n")
    f.write(f"Generated at: {datetime.now()}\n")
    f.write(f"Model: {model_config.name}\n")
    f.write("=" * 50 + "\n\n")
    f.write(cleaned_response)

print(f"\nCleaned response saved to 'llm_trading_analysis_clean.md'")
print(f"Cleaned response length: {len(cleaned_response)} characters")
# Out:
# Sending request to LLM...
# Model: qwen3:14b
# Context size: 20000
# System prompt length: 5175 chars
# User prompt length: 12307 chars
# ==================================================
# 2025-08-05 17:55:33 [debug    ] retry_backoff                  args=() backoff=1 func=<bound method Client.ps of <ollama._client.Client object at 0x77f2f6562350>> kwargs={} timeout=3600
# 2025-08-05 17:55:33 [debug    ] connected_to_ollama            url=http://10.0.0.4:8000
# 2025-08-05 17:55:34 [info     ] sending_generate_request       input_tokens=7749 model=qwen3:14b
# 2025-08-05 17:55:34 [debug    ] retry_backoff                  args=() backoff=1 func=<bound method Client.generate of <ollama._client.Client object at 0x77f2f6562350>> kwargs={'model': 'qwen3:14b', 'system': 'Let\'s make some short term trades on Old School Runescape! Remember, this is just a game. Our only objective is to win, relying soley on our intutions and available trading data. It\'s fun and it\'s free! This is a great sandbox to experiment with an active dataset.\n\nREMEMBER that in this dataset, \'bought_price\' refers to the most recent price at which a buy order was instantly filled. Vice versa for "sold_price". This means that we\'ll submit buy orders targeting the "sold price" and aim to submit sell orders at the "bought price", the opposite of what you might expect. Margin = bought_price - sold_price in this dataset.\n\nAttempt to estimate a timeframe for the anticpated buy and sale. We\'re interested in speed, so long as we can maintain at least 2.1% margin we can price aggressively.\n\nOnly consider the data in #file:over-here!.txt and #file:signals.md\n\nHere\'s an exmple output that is very close to our formatted goals. Two minor, yet important, presentation issues exist\n- It\'s important for us to note the time "ago" a Current Margin was set.\n- Also, we should ensure that every selected item has it\'s strategy price points listed, even if they exceed proposed limits\n\n<example grade="a greate example">\nNow I have all the data I need. Based on the trading data and signals analysis, here are my top OSRS trading recommendations:\n\n🎯 Top OSRS Trading Recommendations (Speed + Margin + Liquidity)\n1. Ham joint - EXPLOSIVE MARGIN OPPORTUNITY ⭐⭐⭐\n    - Current Margin: 134,239 GP (10.79%) - 10m ago\n    - Investment: 1,244,367 GP (buy price) - Excellent risk/reward\n    - Volume: 4 sold/18 bought in 20m, 6 sold/28 bought in 1h\n    - Timeframe: 30-60 minutes\n    - Strategy: Buy at 1,244,367, sell at 1,378,606\n    - Rational: Nearly 11% margin with strong buy pressure (28 vs 6 volume) - buyers are hungry! High buy limit of 100 allows for scaling.\n\n\n2. Smouldering stone - PREMIUM MARGIN PLAY ⭐⭐⭐\n    - Current Margin: 159,528 GP (6.90%) - 19m ago\n    - Investment: 2,311,981 GP (buy price)\n    - Volume: 2 sold/5 bought in 20m, 10 sold/14 bought in 1h\n    - Timeframe: 45 minutes to 1.5 hours\n    - Strategy: Buy at 2,311,981, sell at 2,471,509\n    - Rational: Exceptional 6.9% margin with balanced volume activity. Recent price update shows active market.\n\n\n3. Dragon felling axe - SOLID QUICK FLIP ⭐⭐⭐\n    - Current Margin: 128,573 GP (6.02%) - 13m ago\n    - Investment: 2,134,339 GP (buy price)\n    - Volume: 4 sold/6 bought in 20m, 18 sold/12 bought in 1h\n    - Timeframe: 30-60 minutes\n    - Strategy: Buy at 2,134,339, sell at 2,262,912\n    - Rational: 6% margin with increasing trends across all timeframes - momentum building! Good volume for quick execution.\n\n4. Malediction ward - HIGH MARGIN OPPORTUNITY ⭐⭐\n    - Current Margin: 104,298 GP (4.95%) - 12m ago\n    - Investment: 2,105,128 GP (buy price)\n    - Volume: 1 sold/2 bought in 20m, 14 sold/6 bought in 1h\n    - Timeframe: 1-2 hours\n    - Strategy: Buy at 2,105,128, sell at 2,209,426\n    - Rational: Nearly 5% margin with decent hourly volume. Buy limit of 8 allows multiple units.\n\n5. Antler guard - TRENDING OPPORTUNITY ⭐⭐\n    - Current Margin: 149,969 GP (4.81%) - 12m ago\n    - Investment: 3,119,727 GP (buy price)\n    - Volume: 7 sold/10 bought in 20m, 15 sold/25 bought in 1h\n    - Timeframe: 45 minutes to 1.5 hours\n    - Strategy: Buy at 3,119,727, sell at 3,269,696\n    - Rational: Strong 4.8% margin with increasing buy price trends. Buy pressure exceeding sell pressure (25 vs 15).\n\n6. Soulflame horn - ACTIVE VOLUME PLAY ⭐⭐\n    - Current Margin: 110,658 GP (3.82%) - 11m ago\n    - Investment: 2,898,585 GP (buy price)\n    - Volume: 8 sold/5 bought in 20m, 35 sold/9 bought in 1h\n    - Timeframe: 1-2 hours\n    - Strategy: Bu ...
# 2025-08-05 18:00:39 [info     ] recieved_generate_response     done=True done_reason=stop duration=305.09s model=qwen3:14b output_tokens=2750 tokens_per_second=9.013793965250098
# Cleaned response (without thinking tags):
# ==================================================
# 🎯 Top OSRS Trading Recommendations (Speed + Margin + Liquidity)
# **Fresh Data**: All prices updated within last 15-23 minutes
#
# 1. **Fremennik kilt** - EXPLOSIVE MARGIN OPPORTUNITY ⭐⭐⭐
#     - **Current Margin**: 313,603 GP (7.52%) - 12m ago
#     - **Investment**: 4,485,699 GP (buy price)
#     - **Volume**: 6 sold/2 bought in 20m, 9 sold/26 bought in 1h
#     - **Timeframe**: 45 minutes to 1.5 hours
#     - **Strategy**: Buy at 4,485,699, sell at 4,172,096
#     - **Rational**: Exceptional 7.5% margin with strong buy pressure (26 vs 9 volume). Recent price trends show increasing buy activity and decreasing sell activity – buyers are in control!
#
# 2. **Brimstone ring** - PREMIUM MARGIN PLAY ⭐⭐⭐
#     - **Current Margin**: 283,143 GP (5.04%) - 15m ago
#     - **Investment**: 5,901,437 GP (buy price)
#     - **Volume**: 6 sold/11 bought in 20m, 47 sold/32 bought in 1h
#     - **Timeframe**: 30-60 minutes
#     - **Strategy**: Buy at 5,901,437, sell at 5,618,294
#     - **Rational**: 5.04% margin with strong 1h volume (32 bought vs 47 sold). Buy price increasing, sell price decreasing – a clear flip opportunity.
#
# 3. **Occult necklace** - SOLID QUICK FLIP ⭐⭐⭐
#     - **Current Margin**: 22,302 GP (5.22%) - 9m ago
#     - **Investment**: 449,302 GP (buy price)
#     - **Volume**: 30 sold/12 bought in 20m, 84 sold/112 bought in 1h
#     - **Timeframe**: 30-60 minutes
#     - **Strategy**: Buy at 449,302, sell at 427,000
#     - **Rational**: 5.22% margin with excellent hourly volume (112 bought vs 84 sold). Buy limit of 8 allows quick execution.
#
# 4. **Accursed sceptre (au)** - HIGH MARGIN OPPORTUNITY ⭐⭐
#     - **Current Margin**: 197,684 GP (4.75%) - 15m ago
#     - **Investment**: 4,357,399 GP (buy price)
#     - **Volume**: 4 sold/0 bought in 20m, 10 sold/18 bought in 1h
#     - **Timeframe**: 1-2 hours
#     - **Strategy**: Buy at 4,357,399, sell at 4,159,715
#     - **Rational**: 4.75% margin with emerging buy pressure (18 vs 10 volume). Recent trends show buy price increasing, sell price decreasing.
#
# 5. **Obsidian platelegs** - TRENDING OPPORTUNITY ⭐⭐
#     - **Current Margin**: 30,629 GP (3.58%) - 10m ago
#     - **Investment**: 885,877 GP (buy price)
#     - **Volume**: 48 sold/7 bought in 20m, 32 sold/87 bought in 1h
#     - **Timeframe**: 30-60 minutes
#     - **Strategy**: Buy at 885,877, sell at 855,248
#     - **Rational**: 3.58% margin with strong buy activity (87 vs 32 volume). Buy price and sell price both increasing – momentum building.
#
# 6. **Eclipse moon tassets** - ACTIVE VOLUME PLAY ⭐⭐
#     - **Current Margin**: 31,263 GP (3.78%) - 9m ago
#     - **Investment**: 859,095 GP (buy price)
#     - **Volume**: 9 sold/9 bought in 20m, 47 sold/49 bought in 1h
#     - **Timeframe**: 1-2 hours
#     - **Strategy**: Buy at 859,095, sell at 827,832
#     - **Rational**: 3.78% margin with balanced volume (49 vs 47). Buy limit of 15 allows scaling.
#
# 💰 **High-Value Opportunities** (Exceed 5M Investment Limit)
# 1. **Brimstone ring** - MASSIVE PROFIT POTENTIAL ⭐⭐⭐
#     - **Current Margin**: 283,143 GP (5.04%) - 15m ago
#     - **Investment**: 5,901,437 GP (exceeds 5M limit)
#     - **Volume**: 6 sold/11 bought in 20m, 47 sold/32 bought in 1h
#     - **Strategy**: Buy at 5,901,437, sell at 5,618,294
#     - **Rational**: 5.04% margin with strong 1h volume (32 bought vs 47 sold). Buy price increasing, sell price decreasing – a clear flip opportunity.
#
# ⚡ **Speed Trading Notes**:
# - **Trend Alignment**: Multiple items show increasing buy price trends and decreasing sell price trends – market momentum.
# - **Risk Management**: Start with smaller positions on lower-volume items (e.g., **Accursed sceptre**) to test waters.
# - **Liquidity Check**: Prioritize items with buy limits ≥8 (e.g., **Fremennik kilt**, **Occult necklace**) for faster execution.
#
# 📝 **Item List**
# { "items": ["Brimstone ring", "Fremennik kilt", "Occult necklace", "Accursed sceptre (au)", "Obsidian platelegs", "Eclipse moon tassets"] }
#
# Cleaned response saved to 'llm_trading_analysis_clean.md'
# Cleaned response length: 3992 characters

# %%
with open("over-here!.txt", "r") as f:
    content = f.read()

# Use the loaded_filter's string representation as user prompt context
user_prompt = f"{content}"


print("Sending request to LLM...")
print(f"Model: {model_config.name}")
print(f"Context size: {model_config.options.num_ctx}")
print(f"System prompt length: {len(system_prompt)} chars")
print(f"User prompt length: {len(user_prompt)} chars")
print("=" * 50)

# Get response from LLM
response = get_generate_response(
    model_config=model_config,
    system_prompt=system_prompt,
    user_prompt=user_prompt
)

# Clean the response by removing thinking tags
cleaned_response = remove_thinking_tags(response.response)

print("Cleaned response (without thinking tags):")
print("=" * 50)
print(cleaned_response)

# Save the cleaned response to a separate file
with open("llm_trading_analysis_txt.md", "w") as f:
    f.write("=== Clean LLM Trading Analysis ===\n")
    f.write(f"Generated at: {datetime.now()}\n")
    f.write(f"Model: {model_config.name}\n")
    f.write("=" * 50 + "\n\n")
    f.write(cleaned_response)

print(f"\nCleaned response saved to 'llm_trading_analysis_txt_clean.md'")
print(f"Cleaned response length: {len(cleaned_response)} characters")
# Out:
# Sending request to LLM...
# Model: qwen3:14b
# Context size: 20000
# System prompt length: 5175 chars
# User prompt length: 6931 chars
# ==================================================
# 2025-08-05 18:06:47 [debug    ] retry_backoff                  args=() backoff=1 func=<bound method Client.ps of <ollama._client.Client object at 0x77f2f6562350>> kwargs={} timeout=3600
# 2025-08-05 18:06:47 [debug    ] connected_to_ollama            url=http://10.0.0.4:8000
# 2025-08-05 18:06:47 [info     ] sending_generate_request       input_tokens=4318 model=qwen3:14b
# 2025-08-05 18:06:47 [debug    ] retry_backoff                  args=() backoff=1 func=<bound method Client.generate of <ollama._client.Client object at 0x77f2f6562350>> kwargs={'model': 'qwen3:14b', 'system': 'Let\'s make some short term trades on Old School Runescape! Remember, this is just a game. Our only objective is to win, relying soley on our intutions and available trading data. It\'s fun and it\'s free! This is a great sandbox to experiment with an active dataset.\n\nREMEMBER that in this dataset, \'bought_price\' refers to the most recent price at which a buy order was instantly filled. Vice versa for "sold_price". This means that we\'ll submit buy orders targeting the "sold price" and aim to submit sell orders at the "bought price", the opposite of what you might expect. Margin = bought_price - sold_price in this dataset.\n\nAttempt to estimate a timeframe for the anticpated buy and sale. We\'re interested in speed, so long as we can maintain at least 2.1% margin we can price aggressively.\n\nOnly consider the data in #file:over-here!.txt and #file:signals.md\n\nHere\'s an exmple output that is very close to our formatted goals. Two minor, yet important, presentation issues exist\n- It\'s important for us to note the time "ago" a Current Margin was set.\n- Also, we should ensure that every selected item has it\'s strategy price points listed, even if they exceed proposed limits\n\n<example grade="a greate example">\nNow I have all the data I need. Based on the trading data and signals analysis, here are my top OSRS trading recommendations:\n\n🎯 Top OSRS Trading Recommendations (Speed + Margin + Liquidity)\n1. Ham joint - EXPLOSIVE MARGIN OPPORTUNITY ⭐⭐⭐\n    - Current Margin: 134,239 GP (10.79%) - 10m ago\n    - Investment: 1,244,367 GP (buy price) - Excellent risk/reward\n    - Volume: 4 sold/18 bought in 20m, 6 sold/28 bought in 1h\n    - Timeframe: 30-60 minutes\n    - Strategy: Buy at 1,244,367, sell at 1,378,606\n    - Rational: Nearly 11% margin with strong buy pressure (28 vs 6 volume) - buyers are hungry! High buy limit of 100 allows for scaling.\n\n\n2. Smouldering stone - PREMIUM MARGIN PLAY ⭐⭐⭐\n    - Current Margin: 159,528 GP (6.90%) - 19m ago\n    - Investment: 2,311,981 GP (buy price)\n    - Volume: 2 sold/5 bought in 20m, 10 sold/14 bought in 1h\n    - Timeframe: 45 minutes to 1.5 hours\n    - Strategy: Buy at 2,311,981, sell at 2,471,509\n    - Rational: Exceptional 6.9% margin with balanced volume activity. Recent price update shows active market.\n\n\n3. Dragon felling axe - SOLID QUICK FLIP ⭐⭐⭐\n    - Current Margin: 128,573 GP (6.02%) - 13m ago\n    - Investment: 2,134,339 GP (buy price)\n    - Volume: 4 sold/6 bought in 20m, 18 sold/12 bought in 1h\n    - Timeframe: 30-60 minutes\n    - Strategy: Buy at 2,134,339, sell at 2,262,912\n    - Rational: 6% margin with increasing trends across all timeframes - momentum building! Good volume for quick execution.\n\n4. Malediction ward - HIGH MARGIN OPPORTUNITY ⭐⭐\n    - Current Margin: 104,298 GP (4.95%) - 12m ago\n    - Investment: 2,105,128 GP (buy price)\n    - Volume: 1 sold/2 bought in 20m, 14 sold/6 bought in 1h\n    - Timeframe: 1-2 hours\n    - Strategy: Buy at 2,105,128, sell at 2,209,426\n    - Rational: Nearly 5% margin with decent hourly volume. Buy limit of 8 allows multiple units.\n\n5. Antler guard - TRENDING OPPORTUNITY ⭐⭐\n    - Current Margin: 149,969 GP (4.81%) - 12m ago\n    - Investment: 3,119,727 GP (buy price)\n    - Volume: 7 sold/10 bought in 20m, 15 sold/25 bought in 1h\n    - Timeframe: 45 minutes to 1.5 hours\n    - Strategy: Buy at 3,119,727, sell at 3,269,696\n    - Rational: Strong 4.8% margin with increasing buy price trends. Buy pressure exceeding sell pressure (25 vs 15).\n\n6. Soulflame horn - ACTIVE VOLUME PLAY ⭐⭐\n    - Current Margin: 110,658 GP (3.82%) - 11m ago\n    - Investment: 2,898,585 GP (buy price)\n    - Volume: 8 sold/5 bought in 20m, 35 sold/9 bought in 1h\n    - Timeframe: 1-2 hours\n    - Strategy: Bu ...
# 2025-08-05 18:13:02 [info     ] recieved_generate_response     done=True done_reason=stop duration=373.81s model=qwen3:14b output_tokens=3805 tokens_per_second=10.178948948266637
# Cleaned response (without thinking tags):
# ==================================================
# Now I have all the data I need. Based on the trading data and signals analysis, here are my top OSRS trading recommendations:
#
# 🎯 Top OSRS Trading Recommendations (Speed + Margin + Liquidity)
# 1. **Fremennik kilt** - PREMIUM MARGIN PLAY ⭐⭐⭐
#     - Current Margin: **313,603 GP (7.52%)** - 11m ago
#     - Investment: **4,172,096 GP (sold_price)**
#     - Volume: 2 sold/6 bought in 20m, 26 sold/26 bought in 1h
#     - Timeframe: **30-60 minutes**
#     - Strategy: Buy at **4,172,096**, sell at **4,485,699**
#     - Rational: **7.5% margin** with strong balanced volume (26/26) - buyers and sellers are active. High buy limit of 8 allows for scaling.
#
# 2. **Brimstone ring** - EXPLOSIVE MARGIN OPPORTUNITY ⭐⭐⭐
#     - Current Margin: **283,143 GP (5.04%)** - 8m ago
#     - Investment: **5,618,294 GP (sold_price)**
#     - Volume: 11 sold/6 bought in 20m, 32 sold/47 bought in 1h
#     - Timeframe: **30-60 minutes**
#     - Strategy: Buy at **5,618,294**, sell at **5,901,437**
#     - Rational: **5% margin** with increasing buy pressure (47 vs 32 volume). High flip efficiency (11M) ensures quick execution.
#
# 3. **Accursed sceptre (au)** - SOLID QUICK FLIP ⭐⭐⭐
#     - Current Margin: **197,684 GP (4.75%)** - 23m ago
#     - Investment: **4,159,715 GP (sold_price)**
#     - Volume: 0 sold/4 bought in 20m, 18 sold/24 bought in 1h
#     - Timeframe: **30-60 minutes**
#     - Strategy: Buy at **4,159,715**, sell at **4,357,399**
#     - Rational: **4.75% margin** with strong buy pressure (24 vs 18 volume). Recent price update shows active market.
#
# 4. **Antler guard** - TRENDING OPPORTUNITY ⭐⭐
#     - Current Margin: **143,827 GP (4.32%)** - 11m ago
#     - Investment: **3,328,417 GP (sold_price)**
#     - Volume: 8 sold/2 bought in 20m, 15 sold/19 bought in 1h
#     - Timeframe: **1-2 hours**
#     - Strategy: Buy at **3,328,417**, sell at **3,472,244**
#     - Rational: **4.3% margin** with increasing buy price trends (19 vs 15). Buy limit of NaN suggests caution but strong long-term potential.
#
# 5. **Ahrim's robeskirt** - HIGH MARGIN OPPORTUNITY ⭐⭐
#     - Current Margin: **44,644 GP (3.32%)** - 14m ago
#     - Investment: **1,345,356 GP (sold_price)**
#     - Volume: 10 sold/18 bought in 20m, 39 sold/58 bought in 1h
#     - Timeframe: **30-60 minutes**
#     - Strategy: Buy at **1,345,356**, sell at **1,390,000**
#     - Rational: **3.3% margin** with increasing buy volume (58 vs 39). Strong hourly trends suggest momentum.
#
# 6. **Obsidian platelegs** - ACTIVE VOLUME PLAY ⭐⭐
#     - Current Margin: **30,629 GP (3.58%)** - 8m ago
#     - Investment: **855,248 GP (sold_price)**
#     - Volume: 7 sold/48 bought in 20m, 32 sold/87 bought in 1h
#     - Timeframe: **30-60 minutes**
#     - Strategy: Buy at **855,248**, sell at **885,877**
#     - Rational: **3.58% margin** with strong buy pressure (87 vs 32 volume). Increasing trends across all timeframes = market momentum.
#
# 💰 High-Value Opportunities (Exceed 5M Investment Limit)
# 1. **Fremennik kilt** - ALREADY LISTED ABOVE
# 2. **Brimstone ring** - ALREADY LISTED ABOVE
# 3. **Accursed sceptre (au)** - ALREADY LISTED ABOVE
#
# ⚡ Speed Trading Notes:
# - **Fresh Data**: All prices updated within last 23 minutes
# - **Volume Confirmation**: Focus on items with strong buy/sell activity (e.g., Fremennik kilt, Brimstone ring)
# - **Trend Alignment**: Several items showing increasing price trends (e.g., Obsidian platelegs) = market momentum
# - **Risk Management**: Start with smaller positions on lower-volume items (e.g., Antler guard)
#
# 📝 Item List
# { "items": ["Fremennik kilt", "Brimstone ring", "Accursed sceptre (au)", "Antler guard", "Ahrim's robeskirt", "Obsidian platelegs", "Seers ring", "Eclipse moon tassets", "Dragon impling jar", "Occult necklace"] }
#
# Cleaned response saved to 'llm_trading_analysis_txt_clean.md'
# Cleaned response length: 3765 characters
